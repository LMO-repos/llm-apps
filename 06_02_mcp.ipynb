# %%
import sys
import asyncio

# Fix for Windows issues in Jupyter notebooks
if sys.platform == "win32":
    # 1. Use ProactorEventLoop for subprocess support
    if not isinstance(asyncio.get_event_loop_policy(), asyncio.WindowsProactorEventLoopPolicy):
        asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())
    
    # 2. Redirect stderr to avoid fileno() error when launching MCP servers
    if "ipykernel" in sys.modules:
        sys.stderr = sys.__stderr__

# %%
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())
# Out:
# True

# %% [markdown]
# ## Online MCP

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pprint import pprint
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 from langchain_mcp_adapters.client import MultiServerMCPClient
# ----> 2 from langchain.agents import create_agent
#       3 from langchain.messages import HumanMessage
#       4 from pprint import pprint
#
# File ~\.conda\envs\python3.12\Lib\site-packages\langchain\agents\__init__.py:3
#       1 """Entrypoint to building [Agents](https://docs.langchain.com/oss/python/langchain/agents) with LangChain."""  # noqa: E501
# ----> 3 from langchain.agents.factory import create_agent
#       4 from langchain.agents.middleware.types import AgentState
#       6 __all__ = [
#       7     "AgentState",
#       8     "create_agent",
#       9 ]
#
# File ~\.conda\envs\python3.12\Lib\site-packages\langchain\agents\factory.py:22
#      20 from langchain_core.messages import AIMessage, AnyMessage, SystemMessage, ToolMessage
#      21 from langchain_core.tools import BaseTool
# ---> 22 from langgraph._internal._runnable import RunnableCallable
#      23 from langgraph.constants import END, START
#      24 from langgraph.graph.state import StateGraph
#
# File ~\.conda\envs\python3.12\Lib\site-packages\langgraph\_internal\_runnable.py:43
#      38 from langchain_core.runnables.config import (
#      39     run_in_executor,
#      40     var_child_runnable_config,
#      41 )
#      42 from langchain_core.runnables.utils import Input, Output
# ---> 43 from langchain_core.tracers.langchain import LangChainTracer
#      44 from langgraph.store.base import BaseStore
#      46 from langgraph._internal._config import (
#      47     ensure_config,
#      48     get_async_callback_manager_for_config,
#      49     get_callback_manager_for_config,
#      50     patch_config,
#      51 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_core\tracers\langchain.py:14
#      12 from langsmith import run_trees as rt
#      13 from langsmith import utils as ls_utils
# ---> 14 from tenacity import (
#      15     Retrying,
#      16     retry_if_exception_type,
#      17     stop_after_attempt,
#      18     wait_exponential_jitter,
#      19 )
#      20 from typing_extensions import override
#      22 from langchain_core.env import get_runtime_environment
#
# ImportError: cannot import name 'wait_exponential_jitter' from 'tenacity' (C:\Users\Alireza\AppData\Roaming\Python\Python312\site-packages\tenacity\__init__.py)

# %%
client = MultiServerMCPClient(
    {
        "time": {
            "transport": "stdio",
            "command": "uvx",
            "args": [
                "mcp-server-time",
                "--local-timezone=Asia/Tehran"
            ]
        }
    }
)
tools = await client.get_tools()

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
)

# %%
question = HumanMessage(content="الان ساعت چنده؟")

response = await agent.ainvoke(
    {"messages": [question]}
)

print(response["messages"][-1].content)

# %% [markdown]
# More MCP servers:
#
# https://github.com/punkpeye/awesome-mcp-servers
#
# https://mcp.so/servers?tag=featured
